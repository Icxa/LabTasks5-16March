# %%
#Task7: MapK Networks: Compute Numerical Simulation
import scipy as sp
import scipy.integrate as integrate
import numpy as np
import matplotlib.pyplot as plt


def differt(y, t):
    x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11 = y

    a1 = (k2*x6) + (k15*x11) - (k1*x1*x4) - (k16*x1*x5)
    a2 = (k3*x6) + (k5*x7) + (k10*x9) + (k13*x10) - (x2*x5*(k11 + k12)) - (k4*x2*x4)
    a3 = (k6*x7) + (k8*x8) - (k7*x3*x5)
    a4 = (x6*(k2 + k3)) + (x7*(k5 + k6)) - (k1*x1*x4) - (k4*x2*x4)
    a5 = (k8*x8) + (k10*x9) + (k13*x10) + (k15*x11) - (x2*x5*(k11 + k12)) - (k7*x3*x5) - (k16*x1*x5)
    a6 = (k1*x1*x4) - (x6*(k2 + k3))
    a7 = (k4*x2*x4) - (x7*(k5 + k6))
    a8 = (k7*x3*x5) - (x8*(k8 + k9))
    a9 = (k9*x8) - (k10*x9) + (k11*x2*x5)
    a10 = (k12*x2*x5) - (x10*(k13 + k14))
    a11 = (k14*x10) - (k15*x11) + (k16*x1*x5)

    return [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10, a11]

k1 = 0.02
k4 = 0.032
k7 = 0.045
k9 = 0.092
k15 = 0.086
k2 = 1
k3 = 0.01
k5 = 1
k6 = 15
k8 = 1
k10 = 1
k11 = 0.01
k12 = 0.01
k14 = 0.5
k13 = 1
k16 = 0.0011



#Initial condition
initial_condition = [20, 30, 30, 10, 20, 20, 20, 20, 20, 20, 20]
t_start = 0
t_end = 7000
t_step = 100000
t = np.linspace(t_start, t_end, t_step)

solution = integrate.odeint(differt, initial_condition, t)

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 10), dpi=360)
axes.plot(t, solution[:, 0], "b",
          t, solution[:, 1], "g",
          t, solution[:, 2], "r",
          t, solution[:, 3], "c",
          t, solution[:, 4], "m",
          t, solution[:, 5], "y",
          t, solution[:, 6], "k",
          t, solution[:, 7], "red",
          t, solution[:, 8], "gold",
          t, solution[:, 9], "indigo",
          t, solution[:, 10], "green")

plt.title("MAPK Cascade")
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.show()

# %%
#Task 8

eval1 = solution[:, 0] + solution[:, 1] + solution[:, 2] + solution[:, 3] + solution[:, 4]
eval2 = solution[:, 4] + solution[:, 7] + solution[:, 8] + solution[:, 9] + solution[:, 10]
eval3 = solution[:, 3] + solution[:, 5] + solution[:, 6]
eval4 = solution[:, 0] + solution[:, 1] + solution[:, 2] + solution[:, 5] + solution[:, 6] + \
        solution[:, 7] + solution[:, 8] + solution[:, 9] + solution[:, 10]
eval5 = solution[:, 0] + solution[:, 1] + solution[:, 2] + solution[:, 3] + solution[:, 4] + \
        solution[:, 5] + solution[:, 6] + solution[:, 7] + solution[:, 8] + solution[:, 9] + \
        solution[:, 10]

figeval, axeseval = plt.subplots(nrows=1, ncols=1, figsize=(10, 10), dpi=360)
axeseval.plot(t, eval1, "b",
          t, eval2, "g",
          t, eval3, "r",
          t, eval4, "c",
          t, eval5, "m")
plt.title("MAPK Cascade")
plt.xlabel('Time')
plt.ylabel('Concentration')

plt.show()

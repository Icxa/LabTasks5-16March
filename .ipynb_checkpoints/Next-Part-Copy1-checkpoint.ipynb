# %% [markdown]
# ### Task7: MAPK Networks: Compute Numerical Simulation

# %%
import scipy as sp
import scipy.integrate as integrate
import numpy as np
import matplotlib.pyplot as plt
import os
import subprocess

# %%
def systemOfEquations(variables, time):
    
    x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11 = variables
    
    k1 = 0.02
    k2 = 1
    k3 = 0.01
    k4 = 0.032
    k5 = 1
    k6 = 15
    k7 = 0.045
    k8 = 1
    k9 = 0.092
    k10 = 1
    k11 = 0.01
    k12 = 0.01
    k13 = 1
    k14 = 0.5
    k15 = 0.086
    k16 = 0.0011

    a1 = (k2*x6) + (k15*x11) - (k1*x1*x4) - (k16*x1*x5)
    a2 = (k3*x6) + (k5*x7) + (k10*x9) + (k13*x10) - (x2*x5*(k11 + k12)) - (k4*x2*x4)
    a3 = (k6*x7) + (k8*x8) - (k7*x3*x5)
    a4 = (x6*(k2 + k3)) + (x7*(k5 + k6)) - (k1*x1*x4) - (k4*x2*x4)
    a5 = (k8*x8) + (k10*x9) + (k13*x10) + (k15*x11) - (x2*x5*(k11 + k12)) - (k7*x3*x5) - (k16*x1*x5)
    a6 = (k1*x1*x4) - (x6*(k2 + k3))
    a7 = (k4*x2*x4) - (x7*(k5 + k6))
    a8 = (k7*x3*x5) - (x8*(k8 + k9))
    a9 = (k9*x8) - (k10*x9) + (k11*x2*x5)
    a10 = (k12*x2*x5) - (x10*(k13 + k14))
    a11 = (k14*x10) - (k15*x11) + (k16*x1*x5)

    return [a1, a2, a3, a4, a5, a6, a7, a8, a9, a10, a11]

# %%
def criteriaCheck1(variables):
    x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11 = variables
    print(x5 + x8 + x9 + x10 + x11)
    print(x4 + x6 + x7)
    print(x1 + x2 + x3 + x6 + x7 + x8 + x9 + x10 + x11)
    if (x5 + x8 + x9 + x10 + x11 == 100) and (x4 + x6 + x7 == 50) and (x1 + x2 + x3 + x6 + x7 + x8 + x9 + x10 + x11 == 200):
        return True 
    else:
        return False

# %%
def criteriaCheck2(variables):
    x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11 = variables
    print(x5 + x8 + x9 + x10 + x11)
    print(x4 + x6 + x7)
    print(x1 + x2 + x3 + x6 + x7 + x8 + x9 + x10 + x11)
    if (x5 + x8 + x9 + x10 + x11 == 100) and (x4 + x6 + x7 == 50) and (x1 + x2 + x3 + x6 + x7 + x8 + x9 + x10 + x11 == 500):
        return True 
    else:
        return False

# %%
def createPlotsTask7N8(solution, t):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 10), dpi=360)
    axes.plot(t, solution[:, 0], "black",
              t, solution[:, 1], "green",
              t, solution[:, 2], "red",
              t, solution[:, 3], "cyan",
              t, solution[:, 4], "magenta",
              t, solution[:, 5], "yellow",
              t, solution[:, 6], "blue",
              t, solution[:, 7], "silver",
              t, solution[:, 8], "gold",
              t, solution[:, 9], "indigo",
              t, solution[:, 10], "brown")
    plt.title("MAPK Cascade")
    plt.xlabel('Time')
    plt.ylabel('Concentration')
    #plt.show()

# %%
def evaluateTrajectories(solution, t):
    eval1 = solution[:, 0] + solution[:, 1] + solution[:, 2] + solution[:, 3] + solution[:, 4]
    eval2 = solution[:, 4] + solution[:, 7] + solution[:, 8] + solution[:, 9] + solution[:, 10]
    eval3 = solution[:, 3] + solution[:, 5] + solution[:, 6]
    eval4 = solution[:, 0] + solution[:, 1] + solution[:, 2] + solution[:, 5] + solution[:, 6] + solution[:, 7] + solution[:, 8] + solution[:, 9] + solution[:, 10]
    eval5 = solution[:, 0] + solution[:, 1] + solution[:, 2] + solution[:, 3] + solution[:, 4] + solution[:, 5] + solution[:, 6] + solution[:, 7] + solution[:, 8] + solution[:, 9] + solution[:, 10]
    figeval, axeseval = plt.subplots(nrows=1, ncols=1, figsize=(5, 5), dpi=360)
    axeseval.plot(t, eval1, "b",t, eval2, "g",t, eval3, "r",t, eval4, "c",t, eval5, "m")
    plt.title("MAPK Cascade")
    plt.xlabel('Time')
    plt.ylabel('Concentration')
    plt.show()

# %%
#Initial condition
initial_condition = [20, 30, 30, 10, 20, 20, 20, 20, 20, 20, 20]
if criteriaCheck1(initial_condition) == True:
    t_start = 0
    t_end = 7000
    t_step = 100000
    t = np.linspace(t_start, t_end, t_step)
    solution = integrate.odeint(systemOfEquations, initial_condition, t)
    createPlotsTask7N8(solution, t)
    evaluateTrajectories(solution,t)
else:
    print("Wrong set of inputs")
# Out:
# 100
# 50
# 200

# %%
#Initial condition
initial_condition = [70, 30, 40, 20, 70, 15, 15, 10, 10, 5, 5]
if criteriaCheck1(initial_condition) == True:
    t_start = 0
    t_end = 7000
    t_step = 100000
    t = np.linspace(t_start, t_end, t_step)
    solution = integrate.odeint(systemOfEquations, initial_condition, t)
    createPlotsTask7N8(solution, t)
    evaluateTrajectories(solution,t)
else:
    print("Wrong set of inputs")
# Out:
# 100
# 50
# 200

# %%
#Initial condition
initial_condition = [4,16,10,20,30,40,60,10,10,20,30]
if criteriaCheck1(initial_condition) == True:
    t_start = 0
    t_end = 7000
    t_step = 100000
    t = np.linspace(t_start, t_end, t_step)
    solution = integrate.odeint(systemOfEquations, initial_condition, t)
    createPlotsTask7N8(solution, t)
    evaluateTrajectories(solution,t)
else:
    print("Wrong set of inputs")
# Out:
# 100
# 120
# 200
# Wrong set of inputs

# %% [markdown]
# ### Task 8

# %%
#Initial condition
initial_condition = [120, 120, 140, 20, 20, 20, 20, 10, 10, 30, 30]
if criteriaCheck2(initial_condition) == True:
    t_start = 0
    t_end = 7000
    t_step = 100000
    t = np.linspace(t_start, t_end, t_step)
    solution = integrate.odeint(systemOfEquations, initial_condition, t)
    createPlotsTask7N8(solution, t)
    evaluateTrajectories(solution,t)
else:
    print("Wrong set of inputs")
# Out:
# 100
# 60
# 500
# Wrong set of inputs

# %%
#Initial condition
initial_condition = [200, 100, 80, 20, 10, 15, 15, 10, 10, 10, 60]
if criteriaCheck2(initial_condition) == True:
    t_start = 0
    t_end = 7000
    t_step = 100000
    t = np.linspace(t_start, t_end, t_step)
    solution = integrate.odeint(systemOfEquations, initial_condition, t)
    createPlotsTask7N8(solution, t)
    evaluateTrajectories(solution,t)
else:
    print("Wrong set of inputs")
# Out:
# 100
# 50
# 500

# %%
#Initial condition
initial_condition = [177, 223, 10, 40, 20, 5, 5, 25, 25, 15, 15]
if criteriaCheck2(initial_condition) == True:
    t_start = 0
    t_end = 7000
    t_step = 100000
    t = np.linspace(t_start, t_end, t_step)
    solution = integrate.odeint(systemOfEquations, initial_condition, t)
    createPlotsTask7N8(solution, t)
    evaluateTrajectories(solution,t)
else:
    print("Wrong set of inputs")
# Out:
# 100
# 50
# 500

# %% [markdown]
# ### Bertini

# %%
def parserBertiniOutput(file):
    lines = (line.strip() for line in file)
    nvariables = next(lines)
    dimensionSolution = int(nvariables[21:])
    variables = next(lines)
    rank = next(lines)
    skip1 = next(lines)
    dimensionTitle = next(lines)
    skip2 = next(lines)
    nonSingularTitle = next(lines)
    curline = next(lines)
    results = []
    while curline == '---------------':
        pathNumber = next(lines)
        componentNumber = next(lines)
        estimatedConditionNumber = next(lines)
        components = []
        for i in range(dimensionSolution):
            component = next(lines)
            real, imaginary = component.split(' ')
            component = float(real) + 1j * float(imaginary)
            components.append(component)
        results.append(components)
        multiplicity = next(lines)
        deflations = next(lines)
        curline = next(lines)
    return results

# %%
def modifiedResults(results, atol=1e-08):
    """Biologically feasible solutions are thosee which real and nonnegative"""
    reducedResults = []
    for result in results:
        arrayForm = np.array(result)
        real = np.real(arrayForm)
        imaginary = np.imag(arrayForm)
        if np.allclose(np.zeros(shape=imaginary.shape), imaginary, atol=atol) and np.all(real >= 0):            
            reducedResults.append(real)        
    return np.array(reducedResults)

# %%
parametersModified = ['k19']

# %%
#INPUT file for Bertini
bertiniInputFile = """
CONFIG
TRACKTYPE: 1;
INPUT
function y1, y2, y3, y4, y5, y6, y7, y8, y9, y10, y11, y12, y13, y14;
variable_group x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11;
constant k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19;

k1 = 0.02;
k2 = 1;
k3 = 0.01;
k4 = 0.032;
k5 = 1;
k6 = 15;
k7 = 0.045;
k8 = 1;
k9 = 0.092;
k10 = 1;
k11 = 0.01;
k12 = 0.01;
k13 = 1;
k14 = 0.5;
k15 = 0.086;
k16 = 0.0011;

k17 = 100;
k18 = 50;
k19 = {};

y1 = k2 * x6 + k15 * x11 - k1 * x1 * x4 - k16 * x1 * x5;
y2 = k3 * x6 + k5 * x7 + k10 * x9 + k13 * x10 - x2 * x5 * (k11 + k12) - k4 * x2 * x4;
y3 = k6 * x7 + k8 * x8 - k7 * x3 * x5;
y4 = x6 * (k2 + k3) + x7 * (k5 + k6) - k1 * x1 * x4 - k4 * x2 * x4;
y5 = k8 * x8 + k10 * x9 + k13 * x10 + k15 * x11 - x2 * x5 * (k11 + k12) - k7 * x3 * x5 - k16 * x1 * x5; 
y6 = k1 * x1 * x4 - x6 * (k2 + k3);
y7 = k4 * x2 * x4 - x7 * (k5 + k6);
y8 = k7 * x3 * x5 - x8 * (k8 + k9);
y9 = k9 * x8 - k10 * x9 + k11 * x2 * x5;
y10 = k12 * x2 * x5 - x10 * (k13 + k14);
y11 = k14 * x10 - k15 * x11 + k16 * x1 * x5;

y12 = x5 - k17 + x8 + x9 + x10 + x11;
y13 = x4 - k18 + x6 + x7;
y14 = x1 - k19 + x2 + x3 + x6 + x7 + x8 + x9 + x10 + x11;

END;
"""

# %%
def computation(value, pathForData, subfolderPath):
    subfolder = os.path.join(pathForData, subfolderPath.format(0))
    if not os.path.exists(subfolder):
        os.mkdir(subfolder)
    os.chdir(subfolder)
    with open(os.path.join(subfolder, 'input'), 'w') as file:
        writeData = bertiniInputFile.format(value)
        file.write(writeData)
    subprocess.call(['/home/icxa/Documents/Software/BertiniLinux64_v1.5.1/./bertini'])
    with open(os.path.join(subfolder, 'main_data')) as file:
        data = parserBertiniOutput(file)
        solNum = len(modifiedResults(data))
    return solNum

# %%
pathForData = os.path.abspath('/home/icxa/LabTasks5-16March/Data1')
if not os.path.exists(pathForData):
    os.mkdir(pathForData)
subfolderPath = 'input{:04}/'

# %%
k19PossibleValues = [200, 500]
for value in k19PossibleValues:
    solNum = computation(value, pathForData, subfolderPath)
    print(value, solNum)
# Out:
# 200 1
# 500 3

# %%
lowerBound = 200
upperBound = 500
interval = 0.1
possibleValues = np.arange(lowerBound, upperBound, interval)
print(len(possibleValues))
# Out:
# 3000

# %%
pathForData = os.path.abspath('/home/icxa/LabTasks5-16March/Data3')
if not os.path.exists(pathForData):
    os.mkdir(pathForData)
subfolderPath = 'input{:04}/'

# %%
results = []
for value in possibleValues:
    solNum = computation(value, pathForData, subfolderPath)
    results.append((value, solNum))

# %%
print(results)
# Out:
# [(200.0, 1), (200.09999999999999, 1), (200.19999999999999, 1), (200.29999999999998, 1), (200.39999999999998, 1), (200.49999999999997, 1), (200.59999999999997, 1), (200.69999999999996, 1), (200.79999999999995, 1), (200.89999999999995, 1), (200.99999999999994, 1), (201.09999999999994, 1), (201.19999999999993, 1), (201.29999999999993, 1), (201.39999999999992, 1), (201.49999999999991, 1), (201.59999999999991, 1), (201.6999999999999, 1), (201.7999999999999, 1), (201.89999999999989, 1), (201.99999999999989, 1), (202.09999999999988, 1), (202.19999999999987, 1), (202.29999999999987, 1), (202.39999999999986, 1), (202.49999999999986, 1), (202.59999999999985, 1), (202.69999999999985, 1), (202.79999999999984, 1), (202.89999999999984, 1), (202.99999999999983, 1), (203.09999999999982, 1), (203.19999999999982, 1), (203.29999999999981, 1), (203.39999999999981, 1), (203.4999999999998, 1), (203.5999999999998, 1), (203.69999999999979, 1), (203.79999999999978, 1), (203.89999999999978, 1), (203.99999999999977, 1), (204.09999999999977, 1), (204.19999999999976, 1), (204.29999999999976, 1), (204.39999999999975, 1), (204.49999999999974, 1), (204.59999999999974, 1), (204.69999999999973, 1), (204.79999999999973, 1), (204.89999999999972, 1), (204.99999999999972, 1), (205.09999999999971, 1), (205.1999999999997, 1), (205.2999999999997, 1), (205.39999999999969, 1), (205.49999999999969, 1), (205.59999999999968, 1), (205.69999999999968, 1), (205.79999999999967, 1), (205.89999999999966, 1), (205.99999999999966, 1), (206.09999999999965, 1), (206.19999999999965, 1), (206.29999999999964, 1), (206.39999999999964, 1), (206.49999999999963, 1), (206.59999999999962, 1), (206.69999999999962, 1), (206.79999999999961, 1), (206.89999999999961, 1), (206.9999999999996, 1), (207.0999999999996, 1), (207.19999999999959, 1), (207.29999999999959, 1), (207.39999999999958, 1), (207.49999999999957, 1), (207.59999999999957, 1), (207.69999999999956, 1), (207.79999999999956, 1), (207.89999999999955, 1), (207.99999999999955, 1), (208.09999999999954, 1), (208.19999999999953, 1), (208.29999999999953, 1), (208.39999999999952, 1), (208.49999999999952, 1), (208.59999999999951, 1), (208.69999999999951, 0), (208.7999999999995, 1), (208.89999999999949, 1), (208.99999999999949, 1), (209.09999999999948, 1), (209.19999999999948, 1), (209.29999999999947, 1), (209.39999999999947, 1), (209.49999999999946, 1), (209.59999999999945, 1), (209.69999999999945, 1), (209.79999999999944, 1), (209.89999999999944, 1), (209.99999999999943, 1), (210.09999999999943, 1), (210.19999999999942, 1), (210.29999999999941, 1), (210.39999999999941, 1), (210.4999999999994, 1), (210.5999999999994, 1), (210.69999999999939, 1), (210.79999999999939, 1), (210.89999999999938, 1), (210.99999999999937, 1), (211.09999999999937, 1), (211.19999999999936, 0), (211.29999999999936, 1), (211.39999999999935, 1), (211.49999999999935, 1), (211.59999999999934, 1), (211.69999999999933, 1), (211.79999999999933, 1), (211.89999999999932, 1), (211.99999999999932, 1), (212.09999999999931, 1), (212.19999999999931, 1), (212.2999999999993, 1), (212.3999999999993, 1), (212.49999999999929, 1), (212.59999999999928, 1), (212.69999999999928, 1), (212.79999999999927, 1), (212.89999999999927, 1), (212.99999999999926, 1), (213.09999999999926, 1), (213.19999999999925, 1), (213.29999999999924, 1), (213.39999999999924, 1), (213.49999999999923, 1), (213.59999999999923, 1), (213.69999999999922, 1), (213.79999999999922, 1), (213.89999999999921, 1), (213.9999999999992, 1), (214.0999999999992, 1), (214.19999999999919, 1), (214.29999999999919, 0), (214.39999999999918, 1), (214.49999999999918, 1), (214.59999999999917, 1), (214.69999999999916, 1), (214.79999999999916, 1), (214.89999999999915, 1), (214.99999999999915, 1), (215.09999999999914, 1), (215.19999999999914, 1), (215.29999999999913, 1), (215.39999999999912, 1), (215.49999999999912, 1), (215.59999999999911, 1), (215.69999999999911, 1), (215.7999999999991, 1), (215.8999999999991, 1), (215.99999999999909, 1), (216 ...

# %%
for i in range(len(results)):
    value1, solNum1 = results[i]
    for j in range(i, len(results)):
        value2, solNum2 = results[j]
        if solNum1 == 1 and solNum2 == 3 and value2-value1 <= 0.1:
            print(value1, solNum1, value2, solNum2)
            break
# Out:
# 416.1 1 416.2 3
# 438.1 1 438.2 3
# 449.3 1 449.4 3
# 485.7 1 485.8 3
# 486.9 1 487.0 3

# %%
for i in range(len(results)):
    value1, solNum1 = results[i]
    for j in range(i, len(results)):
        value2, solNum2 = results[j]
        if solNum1 == 1 and solNum2 == 3 and value2-value1 <= 0.2:
            print(value1, solNum1, value2, solNum2)
            break
# Out:
# 409.2 1 409.3 3
# 416.1 1 416.2 3
# 434.3 1 434.4 3
# 438.1 1 438.2 3
# 449.3 1 449.4 3
# 456.0 1 456.1 3
# 457.6 1 457.7 3
# 476.4 1 476.5 3
# 485.7 1 485.8 3
# 486.9 1 487.0 3
# 499.1 1 499.2 3

# %%
for i in range(len(results)):
    value1, solNum1 = results[i]
    for j in range(i, len(results)):
        value2, solNum2 = results[j]
        if solNum1 == 1 and solNum2 == 3 and value2-value1 <= 0.5:
            print(value1, solNum1, value2, solNum2)
            break
# Out:
# 408.8 1 409.3 3
# 408.9 1 409.3 3
# 409.0 1 409.3 3
# 409.1 1 409.3 3
# 409.2 1 409.3 3
# 416.1 1 416.2 3
# 434.3 1 434.4 3
# 438.1 1 438.2 3
# 449.3 1 449.4 3
# 456.0 1 456.1 3
# 457.6 1 457.7 3
# 476.4 1 476.5 3
# 485.7 1 485.8 3
# 486.9 1 487.0 3
# 499.1 1 499.2 3

# %%
for i in range(len(results)):
    value1, solNum1 = results[i]
    for j in range(i, len(results)):
        value2, solNum2 = results[j]
        if solNum1 == 1 and solNum2 == 3 and value2-value1 <= 1:
            print(value1, solNum1, value2, solNum2)
            break
# Out:
# 408.3 1 409.3 3
# 408.4 1 409.3 3
# 408.5 1 409.3 3
# 408.6 1 409.3 3
# 408.7 1 409.3 3
# 408.8 1 409.3 3
# 408.9 1 409.3 3
# 409.0 1 409.3 3
# 409.1 1 409.3 3
# 409.2 1 409.3 3
# 416.1 1 416.2 3
# 434.3 1 434.4 3
# 438.1 1 438.2 3
# 449.3 1 449.4 3
# 456.0 1 456.1 3
# 457.6 1 457.7 3
# 476.4 1 476.5 3
# 485.7 1 485.8 3
# 486.9 1 487.0 3
# 499.1 1 499.2 3

# %%
plt.plot(results)
plt.show()

# %%
tempDict = dict(results)
lists = sorted(tempDict.items()) 
x, y = zip(*lists) # unpack a list of pairs into two tuples
fig, axes = plt.subplots(1,1, figsize=(10, 10))
plt.plot(x, y)
plt.show()
